# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 

import warnings 
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv('wine.csv')

# %%
df
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
 #  setting first column as index

# %%
df
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
d=pd.read_csv('wine.csv',index_col='country')

# %%
d
# Out:
#           Unnamed: 0                                        description  \
# country
# Italy              0  Aromas include tropical fruit, broom, brimston...
# Portugal           1  This is ripe and fruity, a wine that is smooth...
# US                 2  Tart and snappy, the flavors of lime flesh and...
# US                 3  Pineapple rind, lemon pith and orange blossom ...
# US                 4  Much like the regular bottling from 2012, this...
# ...              ...                                                ...
# Germany       129966  Notes of honeysuckle and cantaloupe sweeten th...
# US            129967  Citation is given as much as a decade of bottl...
# France        129968  Well-drained gravel soil gives this wine its c...
# France        129969  A dry style of Pinot Gris, this is crisp with ...
# France        129970  Big, rich and off-dry, this is powered by inte...
#
#                                      designation  points  price  \
# country
# ...

# %%
y=pd.read_csv('wine.csv',usecols=['country','description','taster_name'])

# %%
y
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                taster_name
# 0            Kerin O’Keefe
# 1               Roger Voss
# 2             Paul Gregutt
# 3       Alexander Peartree
# ...

# %%
s=pd.read_csv('wine.csv',index_col=0)

# %%
s
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
s.shape
# Out:
# (129971, 13)

# %%
s.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %%
s.dtypes
# Out:
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
s.isnull()
# Out:
#         country  description  designation  points  price  province  region_1  \
# 0         False        False        False   False   True     False     False
# 1         False        False        False   False  False     False      True
# 2         False        False         True   False  False     False     False
# 3         False        False        False   False  False     False     False
# 4         False        False        False   False  False     False     False
# ...         ...          ...          ...     ...    ...       ...       ...
# 129966    False        False        False   False  False     False      True
# 129967    False        False         True   False  False     False     False
# 129968    False        False        False   False  False     False     False
# 129969    False        False         True   False  False     False     False
# 129970    False        False        False   False  False     False     False
#
# ...

# %%
s.isnull().sum()
# Out:
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# dtype: int64

# %%
s
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
s.drop(['designation'],axis=1,inplace=True)

# %%
s
# Out:
#          country                                        description  points  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...      87
# 1       Portugal  This is ripe and fruity, a wine that is smooth...      87
# 2             US  Tart and snappy, the flavors of lime flesh and...      87
# 3             US  Pineapple rind, lemon pith and orange blossom ...      87
# 4             US  Much like the regular bottling from 2012, this...      87
# ...          ...                                                ...     ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...      90
# 129967        US  Citation is given as much as a decade of bottl...      90
# 129968    France  Well-drained gravel soil gives this wine its c...      90
# 129969    France  A dry style of Pinot Gris, this is crisp with ...      90
# 129970    France  Big, rich and off-dry, this is powered by inte...      90
#
# ...

# %%
s.drop(['region_2','region_1'],axis=1,inplace=True)

# %%
s
# Out:
#          country                                        description  points  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...      87
# 1       Portugal  This is ripe and fruity, a wine that is smooth...      87
# 2             US  Tart and snappy, the flavors of lime flesh and...      87
# 3             US  Pineapple rind, lemon pith and orange blossom ...      87
# 4             US  Much like the regular bottling from 2012, this...      87
# ...          ...                                                ...     ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...      90
# 129967        US  Citation is given as much as a decade of bottl...      90
# 129968    France  Well-drained gravel soil gives this wine its c...      90
# 129969    France  A dry style of Pinot Gris, this is crisp with ...      90
# 129970    France  Big, rich and off-dry, this is powered by inte...      90
#
# ...

# %%
s.drop(['taster_name','taster_twitter_handle'],axis=1,inplace=True)

# %%
s
# Out:
#          country                                        description  points  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...      87
# 1       Portugal  This is ripe and fruity, a wine that is smooth...      87
# 2             US  Tart and snappy, the flavors of lime flesh and...      87
# 3             US  Pineapple rind, lemon pith and orange blossom ...      87
# 4             US  Much like the regular bottling from 2012, this...      87
# ...          ...                                                ...     ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...      90
# 129967        US  Citation is given as much as a decade of bottl...      90
# 129968    France  Well-drained gravel soil gives this wine its c...      90
# 129969    France  A dry style of Pinot Gris, this is crisp with ...      90
# 129970    France  Big, rich and off-dry, this is powered by inte...      90
#
#         price           province  \
# ...

# %%
s['price'] = s['price'].fillna(0)

# %%
s
# Out:
#          country                                        description  points  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...      87
# 1       Portugal  This is ripe and fruity, a wine that is smooth...      87
# 2             US  Tart and snappy, the flavors of lime flesh and...      87
# 3             US  Pineapple rind, lemon pith and orange blossom ...      87
# 4             US  Much like the regular bottling from 2012, this...      87
# ...          ...                                                ...     ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...      90
# 129967        US  Citation is given as much as a decade of bottl...      90
# 129968    France  Well-drained gravel soil gives this wine its c...      90
# 129969    France  A dry style of Pinot Gris, this is crisp with ...      90
# 129970    France  Big, rich and off-dry, this is powered by inte...      90
#
#         price           province  \
# ...

# %%
s.isnull().sum()
# Out:
# country        63
# description     0
# points          0
# price           0
# province       63
# title           0
# variety         1
# winery          0
# dtype: int64

# %%
s.sample(4)
# Out:
#         country                                        description  points  \
# 124387    Italy  The 2006 Pertimali tastes better than the 2006...      90
# 51477   Uruguay  Heavily charred aromas are like a smoldering c...      83
# 31515     Italy  Opening aromas include black berries, toast an...      89
# 27862    France  Named after the grandfather (Aïeul in the loca...      92
#
#         price          province  \
# 124387   55.0           Tuscany
# 51477    18.0        Montevideo
# 31515    65.0           Tuscany
# 27862    55.0  Southwest France
#
#                                                     title            variety  \
# 124387  Livio Sassetti 2006 Pertimali  (Brunello di Mo...  Sangiovese Grosso
# 51477   Familia Traversa 2015 Viña Salort Reserva Tann...             Tannat
# 31515                 Fattoi 2009  Brunello di Montalcino         Sangiovese
# 27862   Château Eugénie 2014 Cuvée Réservée de l'Aïeul...      Malbec-Tannat
#
#                   winery
# ...

# %%
s.dropna(axis=1,inplace=True)

# %%
s
# Out:
#                                               description  points  price  \
# 0       Aromas include tropical fruit, broom, brimston...      87    0.0
# 1       This is ripe and fruity, a wine that is smooth...      87   15.0
# 2       Tart and snappy, the flavors of lime flesh and...      87   14.0
# 3       Pineapple rind, lemon pith and orange blossom ...      87   13.0
# 4       Much like the regular bottling from 2012, this...      87   65.0
# ...                                                   ...     ...    ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...      90   28.0
# 129967  Citation is given as much as a decade of bottl...      90   75.0
# 129968  Well-drained gravel soil gives this wine its c...      90   30.0
# 129969  A dry style of Pinot Gris, this is crisp with ...      90   32.0
# 129970  Big, rich and off-dry, this is powered by inte...      90   21.0
#
#                                                     title  \
# ...

# %%
s.isnull().sum()
# Out:
# description    0
# points         0
# price          0
# title          0
# winery         0
# dtype: int64
