# %% [markdown]
# ## Introduction To Data

# %% [markdown]
# This data shows details of patients and basically based on an analysis on heart disease . The analysing the basic factors with heart disease in patients . It compares many factors like BMI , physical and mental health of the person , if the person is alcoholic etc ....By analysing this data we can conclude about the relation of factors with heart disease .

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 

import warnings 
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## To read the data

# %%
df=pd.read_excel('heartdisease.xls')

# %%
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No               3
# 1                No  20.34      No              No    Yes               0
# 2                No  26.58     Yes              No     No              20
# 3                No  24.21      No              No     No               0
# 4                No  23.71      No              No     No              28
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No               7
# 319791           No  29.84     Yes              No     No               0
# 319792           No  24.24      No              No     No               0
# 319793           No  32.81      No              No     No               0
# 319794           No  46.56      No              No     No               0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# 0                 30          No  Female        55-59     White      Yes
# 1                  0          No  Female  80 or older     White       No
# 2                 30          No    Male        65-69     White      Yes
# 3                  0          No  Female        75-79     White       No
# 4                  0         Yes  Female        40-44     White       No
# ...              ...         ...     ...          ...       ...      ...
# 319790             0         Yes    Male        60-64  Hispanic      Yes
# 319791             0          No    Male        35-39  Hispanic       No
# 319792             0          No  Female        45-49  Hispanic       No
# 319793             0          No  Female        25-29  Hispanic       No
# 319794             0          No  Female  80 or older  Hispanic       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0                   Yes  Very good          5    Yes            No        Yes
# 1                   Yes  Very good          7     No            No         No
# 2                   Yes       Fair          8    Yes            No         No
# 3                    No       Good          6     No            No        Yes
# 4                   Yes  Very good          8     No            No         No
# ...                 ...        ...        ...    ...           ...        ...
# 319790               No       Fair          6    Yes            No         No
# 319791              Yes  Very good          5    Yes            No         No
# 319792              Yes       Good          6     No            No         No
# 319793               No       Good         12     No            No         No
# 319794              Yes       Good          8     No            No         No
#
# [319795 rows x 18 columns]

# %% [markdown]
# ## shape of the data

# %%
df.shape
# Out:
# (319795, 18)

# %% [markdown]
# ## columns in the data

# %%
df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %% [markdown]
# ## Data types of each column in the data

# %%
df.dtypes
# Out:
# HeartDisease         object
# BMI                 float64
# Smoking              object
# AlcoholDrinking      object
# Stroke               object
# PhysicalHealth        int64
# MentalHealth          int64
# DiffWalking          object
# Sex                  object
# AgeCategory          object
# Race                 object
# Diabetic             object
# PhysicalActivity     object
# GenHealth            object
# SleepTime             int64
# Asthma               object
# KidneyDisease        object
# SkinCancer           object
# dtype: object

# %% [markdown]
# ### Observations:-
# It has only 4 columns consist of numerical values and others are objects

# %% [markdown]
# ## To check if there is any null values

# %%
df.isnull()
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0              False  False    False            False   False           False
# 1              False  False    False            False   False           False
# 2              False  False    False            False   False           False
# 3              False  False    False            False   False           False
# 4              False  False    False            False   False           False
# ...              ...    ...      ...              ...     ...             ...
# 319790         False  False    False            False   False           False
# 319791         False  False    False            False   False           False
# 319792         False  False    False            False   False           False
# 319793         False  False    False            False   False           False
# 319794         False  False    False            False   False           False
#
#         MentalHealth  DiffWalking    Sex  AgeCategory   Race  Diabetic  \
# 0              False        False  False        False  False     False
# 1              False        False  False        False  False     False
# 2              False        False  False        False  False     False
# 3              False        False  False        False  False     False
# 4              False        False  False        False  False     False
# ...              ...          ...    ...          ...    ...       ...
# 319790         False        False  False        False  False     False
# 319791         False        False  False        False  False     False
# 319792         False        False  False        False  False     False
# 319793         False        False  False        False  False     False
# 319794         False        False  False        False  False     False
#
#         PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  \
# 0                  False      False      False   False          False
# 1                  False      False      False   False          False
# 2                  False      False      False   False          False
# 3                  False      False      False   False          False
# 4                  False      False      False   False          False
# ...                  ...        ...        ...     ...            ...
# 319790             False      False      False   False          False
# 319791             False      False      False   False          False
# 319792             False      False      False   False          False
# 319793             False      False      False   False          False
# 319794             False      False      False   False          False
#
#         SkinCancer
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ...            ...
# 319790       False
# 319791       False
# 319792       False
# 319793       False
# 319794       False
#
# [319795 rows x 18 columns]

# %%
df.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %% [markdown]
# ### Observations:-
# This shows that tha data donot contain any null values

# %% [markdown]
# ## To get first 5 rows

# %%
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No               3
# 1           No  20.34      No              No    Yes               0
# 2           No  26.58     Yes              No     No              20
# 3           No  24.21      No              No     No               0
# 4           No  23.71      No              No     No              28
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0            30          No  Female        55-59  White      Yes
# 1             0          No  Female  80 or older  White       No
# 2            30          No    Male        65-69  White      Yes
# 3             0          No  Female        75-79  White       No
# 4             0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good          5    Yes            No        Yes
# 1              Yes  Very good          7     No            No         No
# 2              Yes       Fair          8    Yes            No         No
# 3               No       Good          6     No            No        Yes
# 4              Yes  Very good          8     No            No         No

# %% [markdown]
# ## To get last 5 rows

# %%
df.tail()
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 319790          Yes  27.41     Yes              No     No               7
# 319791           No  29.84     Yes              No     No               0
# 319792           No  24.24      No              No     No               0
# 319793           No  32.81      No              No     No               0
# 319794           No  46.56      No              No     No               0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# 319790             0         Yes    Male        60-64  Hispanic      Yes
# 319791             0          No    Male        35-39  Hispanic       No
# 319792             0          No  Female        45-49  Hispanic       No
# 319793             0          No  Female        25-29  Hispanic       No
# 319794             0          No  Female  80 or older  Hispanic       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 319790               No       Fair          6    Yes            No         No
# 319791              Yes  Very good          5    Yes            No         No
# 319792              Yes       Good          6     No            No         No
# 319793               No       Good         12     No            No         No
# 319794              Yes       Good          8     No            No         No

# %% [markdown]
# ## Total information about the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  int64
#  6   MentalHealth      319795 non-null  int64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  int64
#  15  Asthma            319795 non-null  object
#  16  KidneyDisease     319795 non-null  object
#  17  SkinCancer        319795 non-null  object
# dtypes: float64(1), int64(3), object(14)
# memory usage: 43.9+ MB

# %% [markdown]
# ### Observations:-
# This gives the all information about the data

# %% [markdown]
# ## To find if there is any duplicates

# %%
df.duplicated().sum()
# Out:
# 18078

# %%
d=df.drop_duplicates()

# %%
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No               3
# 1                No  20.34      No              No    Yes               0
# 2                No  26.58     Yes              No     No              20
# 3                No  24.21      No              No     No               0
# 4                No  23.71      No              No     No              28
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No               7
# 319791           No  29.84     Yes              No     No               0
# 319792           No  24.24      No              No     No               0
# 319793           No  32.81      No              No     No               0
# 319794           No  46.56      No              No     No               0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# 0                 30          No  Female        55-59     White      Yes
# 1                  0          No  Female  80 or older     White       No
# 2                 30          No    Male        65-69     White      Yes
# 3                  0          No  Female        75-79     White       No
# 4                  0         Yes  Female        40-44     White       No
# ...              ...         ...     ...          ...       ...      ...
# 319790             0         Yes    Male        60-64  Hispanic      Yes
# 319791             0          No    Male        35-39  Hispanic       No
# 319792             0          No  Female        45-49  Hispanic       No
# 319793             0          No  Female        25-29  Hispanic       No
# 319794             0          No  Female  80 or older  Hispanic       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0                   Yes  Very good          5    Yes            No        Yes
# 1                   Yes  Very good          7     No            No         No
# 2                   Yes       Fair          8    Yes            No         No
# 3                    No       Good          6     No            No        Yes
# 4                   Yes  Very good          8     No            No         No
# ...                 ...        ...        ...    ...           ...        ...
# 319790               No       Fair          6    Yes            No         No
# 319791              Yes  Very good          5    Yes            No         No
# 319792              Yes       Good          6     No            No         No
# 319793               No       Good         12     No            No         No
# 319794              Yes       Good          8     No            No         No
#
# [319795 rows x 18 columns]

# %% [markdown]
# ### Observations:-
# This gives if there is any duplicate value and to drop that columns

# %% [markdown]
# ## Statistical description of tha data

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %% [markdown]
# ### Observations:-
# This gives almost all basic functions in statistics.
# * Here,
#   count , mean , standard deviation ,  minimum values , 25 50 75 percentailes and maximum values of all the columns

# %%
df.nunique()
# Out:
# HeartDisease           2
# BMI                 3604
# Smoking                2
# AlcoholDrinking        2
# Stroke                 2
# PhysicalHealth        31
# MentalHealth          31
# DiffWalking            2
# Sex                    2
# AgeCategory           13
# Race                   6
# Diabetic               4
# PhysicalActivity       2
# GenHealth              5
# SleepTime             24
# Asthma                 2
# KidneyDisease          2
# SkinCancer             2
# dtype: int64

# %% [markdown]
# ## Correlation

# %%
df.corr()
# Out:
#                      BMI  PhysicalHealth  MentalHealth  SleepTime
# BMI             1.000000        0.109788      0.064131  -0.051822
# PhysicalHealth  0.109788        1.000000      0.287987  -0.061387
# MentalHealth    0.064131        0.287987      1.000000  -0.119717
# SleepTime      -0.051822       -0.061387     -0.119717   1.000000

# %% [markdown]
# ## Covariance

# %%
df.cov()
# Out:
#                       BMI  PhysicalHealth  MentalHealth  SleepTime
# BMI             40.400010        5.548267      3.242716  -0.473003
# PhysicalHealth   5.548267       63.216019     18.215412  -0.700880
# MentalHealth     3.242716       18.215412     63.285767  -1.367618
# SleepTime       -0.473003       -0.700880     -1.367618   2.062116

# %% [markdown]
# ### Observations:-
# all the factors depend each other

# %% [markdown]
# ## Sort data by Heart Disease

# %%
df.sort_values(by=['HeartDisease'])
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No               3
# 208313           No  20.60      No              No     No              10
# 208312           No  20.18      No              No     No               1
# 208311           No  25.00     Yes              No     No               0
# 208310           No  29.05      No              No     No               3
# ...             ...    ...     ...             ...    ...             ...
# 203419          Yes  23.67      No              No     No               2
# 19990           Yes  32.08     Yes              No     No               0
# 243755          Yes  33.23     Yes              No     No              30
# 20029           Yes  25.51      No              No     No              30
# 117855          Yes  21.89      No              No     No               0
#
#         MentalHealth DiffWalking     Sex  AgeCategory   Race  \
# 0                 30          No  Female        55-59  White
# 208313             0          No  Female        65-69  White
# 208312             3          No  Female        50-54  White
# 208311             3          No  Female        45-49  White
# 208310             0          No    Male        45-49  White
# ...              ...         ...     ...          ...    ...
# 203419             0          No    Male        55-59  White
# 19990              0          No    Male        70-74  White
# 243755             0          No    Male        70-74  White
# 20029              0          No  Female        75-79  White
# 117855             0         Yes    Male  80 or older  White
#
#                        Diabetic PhysicalActivity  GenHealth  SleepTime Asthma  \
# 0                           Yes              Yes  Very good          5    Yes
# 208313                       No              Yes  Excellent          8     No
# 208312                       No              Yes  Very good          5    Yes
# 208311                       No               No       Fair          7     No
# 208310                       No              Yes  Very good          7     No
# ...                         ...              ...        ...        ...    ...
# 203419                       No              Yes  Very good          7     No
# 19990   No, borderline diabetes              Yes       Good          6     No
# 243755                       No              Yes  Very good          7     No
# 20029   No, borderline diabetes              Yes       Fair          6    Yes
# 117855                       No              Yes  Very good          7     No
#
#        KidneyDisease SkinCancer
# 0                 No        Yes
# 208313            No         No
# 208312            No        Yes
# 208311            No         No
# 208310            No         No
# ...              ...        ...
# 203419            No         No
# 19990             No         No
# 243755            No         No
# 20029            Yes         No
# 117855            No        Yes
#
# [319795 rows x 18 columns]

# %% [markdown]
# ## Pivot table

# %%
d1=df.copy()
d1=d1.pivot_table('MentalHealth',columns='AgeCategory',aggfunc='max')
d1
# Out:
# AgeCategory   18-24  25-29  30-34  35-39  40-44  45-49  50-54  55-59  60-64  \
# MentalHealth     30     30     30     30     30     30     30     30     30
#
# AgeCategory   65-69  70-74  75-79  80 or older
# MentalHealth     30     30     30           30

# %% [markdown]
# ### Observations:-
# From this we can see that in all category of age the maximum mental health is 30

# %% [markdown]
# ## Bar graph of BMI and PhysicalHealth

# %%
plt.figure(figsize=(25,10))
plt.bar(df['BMI'],df['PhysicalHealth'])
plt.title('BMI Vs PhysicalHealth',fontsize=15,color='red')
plt.xlabel('BMI',fontsize=15)
plt.ylabel('PhysicalHealth',fontsize=15)
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Observations:-
# We can see the variation in physical health when the BMI is increasing

# %% [markdown]
# ## Bar graph of Physical health and Mental health

# %%
plt.figure(figsize=(18,15))
plt.bar('PhysicalHealth','MentalHealth',data=df,color='green')
plt.show()

# %% [markdown]
# ## Relplot

# %%
sns.relplot(x='AgeCategory',y='PhysicalHealth',hue='BMI',data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observations:-
# From this we can see that the range of BMI is in 15-60 in all age category , in most age category when mental health is less than 5 it is effecting the BMI

# %% [markdown]
# ##  Bar graph of Age category against BMI and Physical health

# %%
df.groupby('AgeCategory')[['BMI','PhysicalHealth']].sum().plot.bar(color=['red','blue'],figsize=(8,5))
plt.ylabel('BMI and PhysicalHealth')
plt.show()

# %% [markdown]
# ### Observations:-
# From this it's clear that ages between 60-74 has higher BMI and Physical health

# %% [markdown]
# ## Bar graph of age category and mental health

# %%
plt.figure(figsize=(12,8))

sns.barplot(x='AgeCategory',y='MentalHealth',data=df,palette='coolwarm_r')
plt.xlabel('AgeCategory',fontsize=15)
plt.show()

# %% [markdown]
# ### Observations:-
# Age between 18-24 , have higher Mental health

# %% [markdown]
# ## Bar chart of Sleep time against Mental health and Physical health

# %%
df.groupby('SleepTime')[['MentalHealth','PhysicalHealth']].sum().plot.bar(color=['green','orange'],figsize=(8,5))
plt.xticks(rotation=90)
plt.ylabel('MentalHealth and PhysicalHealth ')
plt.show()

# %% [markdown]
# ### Observations:-
# From this we can see that people who sleep 6-8 hrs has good mental as well as physical health and also we can see that those who sleep more than 8 hrs, doesn't have good physical and mental health

# %% [markdown]
# ## Heat map

# %%
n_data=['BMI','AgeCategory','MentalHealth','PhysicalHealth']
plt.figure(figsize=(10,5))
sns.heatmap(df[n_data].corr(),annot=True,fmt='.4f',cmap='coolwarm_r',center=0)
plt.show()

# %% [markdown]
# ## Line plot

# %%
plt.figure(figsize=(10,4))
sns.lineplot('MentalHealth','SleepTime',data=df,color='r',label='MentalHealth')
plt.legend()
plt.show()

# %% [markdown]
# ### Observations:-
# We can see that mental health and sleep time are related to each other if there is a good sleep(6-8) there is also good mental health

# %% [markdown]
# ## Histograms

# %%
df.hist(bins=20,figsize=(20,15),color='red')
plt.show()

# %% [markdown]
# ## Pair plot

# %%
sns.pairplot(df,hue='MentalHealth')
plt.show()

# %% [markdown]
# ### Observations:-
# Here we plotted mental health as hue against each column like we seen that good sleep , good physical health and an good BMI can influence  mental health of a person also.

# %% [markdown]
# ## scatter plot

# %%
sns.scatterplot(x='MentalHealth',y='SleepTime',hue='PhysicalHealth',data=df)
plt.show()

# %% [markdown]
# ### Observations:-
# We can see that those who have good mental health and good sleep time (6-8) have good physical health also

# %% [markdown]
# ## Cat plot

# %%
sns.catplot(x='MentalHealth',y='SleepTime',hue='PhysicalHealth',data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## observations:-

# %% [markdown]
# ## Cat plot of box kind

# %%
sns.catplot(x='MentalHealth',y='SleepTime',kind='boxen',data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observations:-

# %% [markdown]
# ## kde plot

# %%
sns.kdeplot(df['SleepTime'])
plt.show()

# %% [markdown]
# ### Observations:-
# Here we can see that most people have a good sleep time that is 6-8 hrs

# %%
sns.kdeplot(df['SleepTime'],df['MentalHealth'],color='green',shade=True)
plt.show()

# %% [markdown]
# ### Observations:-
# This compares  the sleep time and mental health of each person. Here we can see that sleep time less than 5 hrs and more than 10 hrs doesnot have a good mental health

# %% [markdown]
# ## Voilin plot

# %%
sns.violinplot(x=df.MentalHealth)
plt.show()

# %% [markdown]
# ### Observations:-
# This  shows the value range of mental health .
# The mental health that more people have is between 0-5

# %% [markdown]
# ## Swarm plot

# %%
sns.swarmplot(df['SleepTime'])
plt.show()

# %% [markdown]
# ### Observations:-
