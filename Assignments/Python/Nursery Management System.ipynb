# %%
class Nursery:
    
       
    def displayinformation():
        print("All about our nursery : ")
        print("**************************************")
        print("Welcome to our nursery. If you want to make your garden attractive and to feed your family with tasty food made of organical vegetables,this is the best choice. We provide all kinds of plants ,vegetable plants, fertilizers. Our nursery is located in the heart of thrissur,in the swaraj round near kalyan silks.Our services are available on monday - saturday from 9 am to 6 pm.For any anquiry Ph :- 8869654213. Come and enjoy planting.....f ")
       
    
class employees:
    
    
    def __init__(self,Employees):
        self.availableemployees=Employees
        

    
    def displayemployees(self):
        print("Available workers are:")
        for employees in self.availableemployees:
            print(employees)
            
    def deletemployee(self,requestedname):
        self.requestedname=requestedname
        if requestedname in self.employees:
            print("The requested name has been removed.")
            self.availableemployees.remove(self.requestedname)
        else:
            print("Sorry the requested name is currently not in list.")
            
    def addemployees(self,newemployee):
        self.newemployee=newemployee
        if newemployee in self.availableemployees:
            print("Employee already exist")
        else:
            print("New employee is Added Successfully.")
        
            self.availableemployees.append(self.newemployee)
      
        

class plants:
    
    def __init__(self,plants):
        self.availableplants=plants
        
    
    def displayAvailableplants(self):
        print("The plants we have are:")
        print("*********************")
        for plants in self.availableplants:
            print(plants)
            
            
            
    def deleteplant(self,requestedplant):
        self.requestedplant=requestedplant
        if requestedplant in self.availableplants:
            print("The plant you requested has now been removed ")
            self.availableplants.remove(requestedplant)
        else:
            print("Sorry the plant you have requested to delete, is currently not in nursery.")
            
            
    def addplant(self,newplant):
        self.newplant=newplant
        if self.newplant in self.availableplant:
            print("The plant already exist")
        else:
            print("New Plant is Added Successfully.")
            self.availableplants.append(newplant)
        
       
        
        
class vegetableplants:
    
    def __init__(self,vegetableplants):
        self.availablevegetableplants=vegetableplants
        
        
    def displayAvailable_vegetableplants(self):
        
        print("The vegetable_plants we have are:")
        print("*********************")
        for vegetableplants in self.availablevegetableplants:
            print(vegatableplants)
            
            
            
    def delete_vegetableplant(self,requested):
        self.requested=requested
        if self.requested in self.availablevegetableplants:
            print("The plant you requested has now been removed ")
            self.availablevegetableplants.remove(self.requested)
        else:
            print("Sorry the plant you have requested to delete, is currently not in nursery.")
            
            
    def add_vegetableplant(self,newplant):
        self.newplant=newplant
        if self.newplant in self.availableplant:
            print("The plant already exist")
        else:
            print("New Plant is Added Successfully.")
            self.availableplants.append(newplant)
        
class fertilizers:
    
    def __init__(self,fertilizers):
        self.availablefertilizers=fertilizers
        
    
    def displayAvailablefertilizers(self):
        print("The fertilizers we have are:")
        print("*********************")
        for fertilizers in self.availablefertilizers:
            print(fertilizers)
            
    def deletefertilizer(self,requestedfertilizer):
        self.requestedfertilizer=requestedfertilizer
        if requestedfertilizer in self.availablefertilizers:
            print("The fertilizer you requested has now been removed ")
            self.availablefertilizers.remove(self.requestedfertilizer)
        else:
            print("Sorry the fertilizer you have requested to delete, is currently not in nursery.")
            
    def addfertilizer(self,newfertilizer):
        self.newfertilizer=newfertilizer
        if newfertilizer in selfr.availablefertilizers:
            print("Fertilizer already exist")
        else:
            print("New fertilizer is Added Successfully.")
            self.availablefertilizers.append(newfertilizer)
            
      
    
        
class owner:
    
    def delplant(self):
        print("Enter the name of the plant you'd like to delete:")
        self.plants=input()
        return self.plants
    
    def newplant(self):
        print("Enter the name of the plant you'd like to add:")
        self.plants=input()
        return self.plants
    
    def delvegetableplant(self):
        print("Enter the name of the vegetable plant you'd like to delete:")
        self.vegetableplants=input()
        return self.vegetableplants
    
    def newvegatableplant(self):
        print("Enter the name of the vegetable plant you'd like to add:")
        self.vegetableplants=input()
        return self.vegetableplants
    
    def delemployee(self):
        print("Enter the name of the employee you'd like to delete:")
        self.employees=input()
        return self.employees
    
    def newemployee(self):
        print("Enter the name of the employee you'd like to add:")
        self.employees=input()
        return self.employees
    
    def delfertilizer(self):
        print("Enter the name of the employee you'd like to delete:")
        self.fertilizers=input()
        return self.fertilizers
    
    def newfertilizer(self):
        print("Enter the name of the employee you'd like to add:")
        self.fertilizers=input()
        return self.fertilizers
    
    
def call():
    Employee=employees(["uma","shobha","meera","kavya"])
    
    Plants=plants(["1. Roses :35/-","2. Orchids : 300/-","3. Lilly : 250/-","4. Jasmine : 50/-","5. Moneyplants : 35/-","6. Sunflower : 90/-"])
    Vegetableplants=vegetableplants(["1. Chilly : 25/-","2. Tomato : 25/-","3. Carrot : 40/-","4. Cucumber : 25/-"," 5. Pumkin : 25/-","6. Spinach : 10/-"])
    Fertilizers=fertilizers(["1. Manure ( 1 kg): 75/-","2. Compost(1 kg): 80/-","3.Rock phosphate(1 kg): 200/-","4.Bone meal(1 kg): 250/-"])
    Owner=owner()                           
    
    done=False
    while done==False:
        
        print("""        NURSERY       
         **********MAIN MENU************
         1. About
         2. Display employees
         3. Add employee
         4. Delete employee
         5. Display plants and their rates
         6. Add plant
         7. Delete plant
         8. Display vegetable plants and their rates
         9. Add vegetable plant
         10. Delete vegtable plant
         11. Display fertilizers and their rates
         12. Add fertilizer
         13. Delete fertilizer
         14. Exit""")
        
        
        try:
            choice=int(input("Enter choice:"))
        
            if choice==1:
                Nursery.displayinformation()
            elif choice==2:
                Employee.displayemployees()
            elif choice==3:
                Employee.addemployees(Owner.newemployee())
            elif choice==4:
                Employee.deletemployee(Owner.delemployee())
            elif choice==5:
                Plants.displayAvailableplants()
            elif choice==6:
                Plants.addplant(Owner.newplant())
            elif choice==7:
                Plants.deleteplant(Owner.delplant())
            elif choice==8:
                Vegetableplants.displayAvailable_vegetableplants()    
            elif choice==9:
                Vegetableplants.add_vegetableplant(Owner.newvegatableplant())   
            elif choice==10:
                Vegetableplants.delete_vegetableplant(Owner.delvegetableplant())  
            elif choice==11:
                Fertilizers.displayAvailablefertilizers() 
            elif choice==12:
                Fertilizers.addfertilizer(Owner.newfertilizer())
            elif choice==13:
                Fertilizers.deletefertilizer(Owner.delfertilizer())
            elif choice==14:
                break
                
        except:
            print("inavlid choice")
                
        
    
        
call()
# Out:
#         NURSERY
#          **********MAIN MENU************
#          1. About
#          2. Display employees
#          3. Add employee
#          4. Delete employee
#          5. Display plants and their rates
#          6. Add plant
#          7. Delete plant
#          8. Display vegetable plants and their rates
#          9. Add vegetable plant
#          10. Delete vegtable plant
#          11. Display fertilizers and their rates
#          12. Add fertilizer
#          13. Delete fertilizer
#          14. Exit
# Enter choice:2
# Available workers are:
# uma
# shobha
# meera
# kavya
#         NURSERY
#          **********MAIN MENU************
#          1. About
#          2. Display employees
#          3. Add employee
#          4. Delete employee
#          5. Display plants and their rates
#          6. Add plant
#          7. Delete plant
#          8. Display vegetable plants and their rates
#          9. Add vegetable plant
#          10. Delete vegtable plant
# ...
